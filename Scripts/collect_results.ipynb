# %% [markdown]
# # Loading Datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Extract results

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults.zip'
extract_to = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults'

# Extraindo
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-00a1a4566dad> in <cell line: 8>()
#       7 # Extraindo
#       8 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
# ----> 9     zip_ref.extractall(extract_to)
#
# /usr/lib/python3.10/zipfile.py in extractall(self, path, members, pwd)
#    1658
#    1659         for zipinfo in members:
# -> 1660             self._extract_member(zipinfo, path, pwd)
#    1661
#    1662     @classmethod
#
# /usr/lib/python3.10/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1713         with self.open(member, pwd=pwd) as source, \
#    1714              open(targetpath, "wb") as target:
# -> 1715             shutil.copyfileobj(source, target)
#    1716
#    1717         return targetpath
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     185                 fdst_write(mv)
#     186
# --> 187 def copyfileobj(fsrc, fdst, length=0):
#     188     """copy data from file-like object fsrc to file-like object fdst"""
#     189     # Localize variable access to minimize overhead.
#
# KeyboardInterrupt:

# %% [markdown]
# # Select Community results

# %%
import os
import shutil

# Caminhos
community_root_path = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Community'
output_path = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Community'

# Criar a pasta de saída
os.makedirs(output_path, exist_ok=True)

# Função para copiar o arquivo `results_0.csv`
def copy_results_file(project_name, year, results_path):
    output_year_path = os.path.join(output_path, project_name, year)
    os.makedirs(output_year_path, exist_ok=True)

    source_file = os.path.join(results_path, "results_0.csv")
    if os.path.exists(source_file):
        destination_file = os.path.join(output_year_path, f"{project_name}_{year}_results_0.csv")
        shutil.copy2(source_file, destination_file)
        print(f"Arquivo results_0.csv copiado para {destination_file}")
    else:
        print(f"Arquivo results_0.csv não encontrado em {source_file}")

# Percorrer diretórios
for project_folder in os.listdir(community_root_path):
    project_path = os.path.join(community_root_path, project_folder)
    if not os.path.isdir(project_path):
        continue

    project_name = project_folder

    for year_folder in os.listdir(project_path):
        year_path = os.path.join(project_path, year_folder)
        if not os.path.isdir(year_path):
            continue

        # Procurar automaticamente pela pasta `results` descendo duas subpastas após o ano
        found_results_path = None
        for first_level_folder in os.listdir(year_path):
            first_level_path = os.path.join(year_path, first_level_folder)
            if not os.path.isdir(first_level_path):
                continue
            for second_level_folder in os.listdir(first_level_path):
                second_level_path = os.path.join(first_level_path, second_level_folder)
                if not os.path.isdir(second_level_path):
                    continue

                # Verifica se a pasta `results` está no segundo nível
                results_path = os.path.join(second_level_path, "results")
                if os.path.exists(results_path):
                    found_results_path = results_path
                    break
            if found_results_path:
                break

        # Se encontramos a pasta `results`, copiamos o arquivo `results_0.csv`
        if found_results_path:
            print(f"Processando {project_name} para o ano {year_folder}...")
            copy_results_file(project_name, year_folder, found_results_path)
        else:
            print(f"Pasta 'results' não encontrada para {project_name} no ano {year_folder}")

print("Processo de extração de dados concluído com sucesso!")

# %% [markdown]
# # Select Code results

# %%
import os
import shutil
import csv

# Caminhos
code_root_path = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code'
output_path_code = '/content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code'

# Criar a pasta de saída
os.makedirs(output_path_code, exist_ok=True)

# Função para copiar o arquivo `typeMetrics.csv`
def copy_type_metrics_file(project_name, year, type_metrics_path):
    output_year_path = os.path.join(output_path_code, project_name, year)
    os.makedirs(output_year_path, exist_ok=True)

    source_file = os.path.join(type_metrics_path, "typeMetrics.csv")

    # Validar se o arquivo tem mais de uma linha
    with open(source_file, 'r') as csv_file:
        reader = csv.reader(csv_file)
        row_count = sum(1 for row in reader)

    if row_count > 1:
        destination_file = os.path.join(output_year_path, f"{project_name}_{year}_typeMetrics.csv")
        shutil.copy2(source_file, destination_file)
        print(f"Arquivo typeMetrics.csv copiado para {destination_file}")
    else:
        print(f"Arquivo typeMetrics.csv em {source_file} não contém mais de uma linha. Ignorado.")

# Percorrer diretórios
for project_folder in os.listdir(code_root_path):
    project_path = os.path.join(code_root_path, project_folder)
    if not os.path.isdir(project_path):
        continue

    project_name = project_folder

    for year_folder in os.listdir(project_path):
        year_path = os.path.join(project_path, year_folder)
        if not os.path.isdir(year_path):
            continue

        # Verificar se o arquivo `typeMetrics.csv` existe na pasta do ano
        type_metrics_file = os.path.join(year_path, "typeMetrics.csv")

        if os.path.exists(type_metrics_file):
            print(f"Processando {project_name} para o ano {year_folder}...")
            copy_type_metrics_file(project_name, year_folder, year_path)
        else:
            print(f"Arquivo 'typeMetrics.csv' não encontrado para {project_name} no ano {year_folder}")

print("Processo de extração de dados concluído com sucesso!")
# Out:
# Processando traffic-manager-dotnet-manage-profiles para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/traffic-manager-dotnet-manage-profiles/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando traffic-manager-dotnet-manage-profiles para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/traffic-manager-dotnet-manage-profiles/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-dotnet-manage-azure-container-registry para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-dotnet-manage-azure-container-registry/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-dotnet-manage-azure-container-registry para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-dotnet-manage-azure-container-registry/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-dotnet-manage-azure-container-registry-with-webhooks para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-dotnet-manage-azure-container-registry-with-webhooks/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-dotnet-manage-azure-container-registry-with-webhooks para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-dotnet-manage-azure-container-registry-with-webhooks/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-tasks para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-tasks/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando acr-tasks para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/acr-tasks/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-b2c-dotnet-desktop para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-b2c-dotnet-desktop/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-b2c-dotnet-desktop para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-b2c-dotnet-desktop/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-b2c-javascript-nodejs-webapi para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-b2c-javascript-nodejs-webapi/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-b2c-xamarin-native para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-b2c-xamarin-native/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-b2c-xamarin-native para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-b2c-xamarin-native/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-dotnet-native-aspnetcore-v2 para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-dotnet-native-aspnetcore-v2/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-dotnetcore-console-up-v2 para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-dotnetcore-console-up-v2/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando active-directory-dotnetcore-console-up-v2 para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/active-directory-dotnetcore-console-up-v2/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando ai-rag-chat-evaluator para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/ai-rag-chat-evaluator/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-cloudfront-secure-static-site para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-cloudfront-secure-static-site/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-cloudfront-secure-static-site para o ano 2022...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-cloudfront-secure-static-site/2022/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-cloudfront-secure-static-site para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-cloudfront-secure-static-site/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-cloudfront-secure-static-site para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-cloudfront-secure-static-site/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-kendra-langchain-extensions para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-kendra-langchain-extensions/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-kendra-langchain-extensions para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/amazon-kendra-langchain-extensions/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando amazon-kinesis-analytics-beam-taxi-consumer para o ano 2021...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/amazon-kinesis-analytics-beam-taxi-consumer/2021/amazon-kinesis-analytics-beam-taxi-consumer_2021_typeMetrics.csv
# Processando amazon-kinesis-analytics-beam-taxi-consumer para o ano 2022...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/amazon-kinesis-analytics-beam-taxi-consumer/2022/amazon-kinesis-analytics-beam-taxi-consumer_2022_typeMetrics.csv
# Processando amazon-kinesis-analytics-streaming-etl para o ano 2020...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code
o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/cdn-dotnet-manage-cdn/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando cognitive-services-python-sdk-samples para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/cognitive-services-python-sdk-samples/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando cognitive-services-python-sdk-samples para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/cognitive-services-python-sdk-samples/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando communication-services-android-calling-hero para o ano 2021...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/communication-services-android-calling-hero/2021/communication-services-android-calling-hero_2021_typeMetrics.csv
# Processando communication-services-android-calling-hero para o ano 2022...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/communication-services-android-calling-hero/2022/communication-services-android-calling-hero_2022_typeMetrics.csv
# Processando communication-services-ui-library-maui para o ano 2022...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/communication-services-ui-library-maui/2022/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando communication-services-ui-library-maui para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/communication-services-ui-library-maui/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando communication-services-ui-library-maui para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/communication-services-ui-library-maui/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando communication-services-ui-library-xamarin para o ano 2022...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/communication-services-ui-library-xamarin/2022/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando communication-services-ui-library-xamarin para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/communication-services-ui-library-xamarin/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando compute-dotnet-manage-user-assigned-msi-enabled-virtual-machine para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/compute-dotnet-manage-user-assigned-msi-enabled-virtual-machine/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando compute-dotnet-manage-user-assigned-msi-enabled-virtual-machine para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/compute-dotnet-manage-user-assigned-msi-enabled-virtual-machine/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando compute-dotnet-manage-vm-async para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/compute-dotnet-manage-vm-async/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando compute-dotnet-manage-vm-async para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/compute-dotnet-manage-vm-async/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando cosmos-dotnet-core-getting-started para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/cosmos-dotnet-core-getting-started/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando cost-effective-aws-deployment-of-comfyui para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/cost-effective-aws-deployment-of-comfyui/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando custom-web-experience-with-amazon-q-business para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/custom-web-experience-with-amazon-q-business/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando digital-twins-iothub-integration para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/digital-twins-iothub-integration/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando digital-twins-iothub-integration para o ano 2021...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/digital-twins-iothub-integration/2021/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando dns-dotnet-host-and-manage-your-domains para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/dns-dotnet-host-and-manage-your-domains/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando dns-dotnet-host-and-manage-your-domains para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/dns-dotnet-host-and-manage-your-domains/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando durablefunctions-apiscraping-dotnet para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/durablefunctions-apiscraping-dotnet/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando durablefunctions-apiscraping-dotnet para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/durablefunctions-apiscraping-dotnet/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub-events para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub-events/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub-events para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub-events/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub-geo-disaster-recovery para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub-geo-disaster-recovery/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando eventhub-dotnet-manage-event-hub-geo-disaster-recovery para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/eventhub-dotnet-manage-event-hub-geo-disaster-recovery/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando Hybrid-CSharp-Samples para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/Hybrid-CSharp-Samples/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando Hybrid-Golang-Samples para o ano 2019...
# ...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/ms-identity-aspnet-daemon-webapp/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando ms-identity-aspnet-daemon-webapp para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/ms-identity-aspnet-daemon-webapp/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando ms-identity-node para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/ms-identity-node/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando ms-identity-python-webapp-django para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/ms-identity-python-webapp-django/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando msk-config-providers para o ano 2023...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/msk-config-providers/2023/msk-config-providers_2023_typeMetrics.csv
# Processando network-dotnet-create-simple-internet-facing-load-balancer para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-create-simple-internet-facing-load-balancer/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-create-simple-internet-facing-load-balancer para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-create-simple-internet-facing-load-balancer/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internal-load-balancers para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internal-load-balancers/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internal-load-balancers para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internal-load-balancers/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internal-load-balancers para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internal-load-balancers/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internet-facing-load-balancers para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internet-facing-load-balancers/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internet-facing-load-balancers para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internet-facing-load-balancers/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-internet-facing-load-balancers para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-internet-facing-load-balancers/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-ip-address para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-ip-address/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-ip-address para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-ip-address/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-ip-address para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-ip-address/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-interface para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-interface/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-interface para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-interface/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-interface para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-interface/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-peering para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-peering/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-peering para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-peering/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-security-group para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-security-group/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-security-group para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-security-group/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-network-security-group para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-network-security-group/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network-async para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network-async/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network-to-virtual-network-vpn-connection para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network-to-virtual-network-vpn-connection/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network-to-virtual-network-vpn-connection para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network-to-virtual-network-vpn-connection/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network-with-site-to-site-vpn-connection para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network-with-site-to-site-vpn-connection/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando network-dotnet-manage-virtual-network-with-site-to-site-vpn-connection para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/network-dotnet-manage-virtual-network-with-site-to-site-vpn-connection/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando python-data-science-template para o ano 2021...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/python-data-science-template/2021/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando python-data-science-template para o ano 2022...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/python-data-science-template/2022/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando qnabot-on-aws-plugin-samples para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/qnabot-on-aws-plugin-samples/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando qnabot-on-aws-plugin-samples para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/qnabot-on-aws-plugin-samples/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando reactive-refarch-cloudformation para o ano 2018...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/reactive-refarch-cloudformation/2018/reactive-refarch-cloudformation_2018_typeMetrics.csv
# Processando reactive-refarch-cloudformation para o ano 2019...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/reactive-refarch-cloudformation/2019/reactive-refarch-cloudformation_2019_typeMetrics.csv
# Processando reactive-refarch-cloudformation para o ano 2020...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/reactive-refarch-cloudformation/2020/reactive-refarch-cloudformation_2020_typeMetrics.csv
# Processando reactive-refarch-cloudformation para o ano 2024...
# Arquivo typeMetrics.csv copiado para /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/AnalysisData_Code/reactive-refarch-cloudformation/2024/reactive-refarch-cloudformation_2024_typeMetrics.csv
# Processando resources-dotnet-deploy-using-arm-template-with-progress para o ano 2016...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/resources-dotnet-deploy-using-arm-template-with-progress/2016/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando resources-dotnet-deploy-using-arm-template-with-progress para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/resources-dotnet-deploy-using-arm-template-with-progress/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando resources-dotnet-deploy-using-arm-template-with-progress para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/resources-dotnet-deploy-using-arm-template-with-progress/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando sagemaker-studio-apps-lifecycle-config-examples para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/sagemaker-studio-apps-lifecycle-config-examples/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando sagemaker-studio-apps-lifecycle-config-examples para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/sagemaker-studio-apps-lifecycle-config-examples/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando search-dotnet-getting-started para o ano 2019...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/search-dotnet-getting-started/2019/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando search-dotnet-getting-started para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/search-dotnet-getting-started/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando serverless-store-finder para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/serverless-store-finder/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando simple-websockets-chat-app para o ano 2020...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/simple-websockets-chat-app/2020/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando spark-on-aws-lambda para o ano 2023...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/spark-on-aws-lambda/2023/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando spark-on-aws-lambda para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/spark-on-aws-lambda/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processando support-insights-with-amazon-q para o ano 2024...
# Arquivo typeMetrics.csv em /content/drive/MyDrive/Arquivos_Mestrado_Arthur_Ramires/Metodologia/ExtractionResults/ExtractionResults/Code/support-insights-with-amazon-q/2024/typeMetrics.csv não contém mais de uma linha. Ignorado.
# Processo de extração de dados concluído com sucesso!
